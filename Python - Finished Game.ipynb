# %%
def introduction():
    """This is the introduction section of the game"""
    life = 1
    while life == 1:
        #setup
        import time
        import sys
        inventory = []


        answer = input(prompt = """[use only lower case... throughout the entire game...
                if there is a choice, type the selected options from the choices at the end of 
                the sentence and press enter.] ex:(forward/left/right/back) 
                Now, Would you like to start the game? (yes/no)\n""").lower().strip()
        #The above is the condition if you want to start the game
        if answer == "yes":
            name = input(prompt = f"""
Welcome to...
    ██╗   ██╗███╗   ██╗██╗██╗   ██╗███████╗██████╗ ███████╗███████╗     ██████╗ ██████╗ ██████╗ ██████╗ 
    ██║   ██║████╗  ██║██║██║   ██║██╔════╝██╔══██╗██╔════╝██╔════╝    ██╔════╝██╔═══██╗██╔══██╗██╔══██╗
    ██║   ██║██╔██╗ ██║██║██║   ██║█████╗  ██████╔╝███████╗█████╗      ██║     ██║   ██║██████╔╝██████╔╝
    ██║   ██║██║╚██╗██║██║╚██╗ ██╔╝██╔══╝  ██╔══██╗╚════██║██╔══╝      ██║     ██║   ██║██╔══██╗██╔═══╝ 
    ╚██████╔╝██║ ╚████║██║ ╚████╔╝ ███████╗██║  ██║███████║███████╗    ╚██████╗╚██████╔╝██║  ██║██║██╗  
     ╚═════╝ ╚═╝  ╚═══╝╚═╝  ╚═══╝  ╚══════╝╚═╝  ╚═╝╚══════╝╚══════╝     ╚═════╝ ╚═════╝ ╚═╝  ╚═╝╚═╝╚═╝  
                                                                             We hope you have a Galactic day!


        what is your name, user?\n""").capitalize().strip()
            print(f"""greetings {name}, let's start your journey... from here on out, if you see this symbol "¥" just hit [enter] ¥\n""")
            robot_name = input(prompt = f"""Welcome resident [01337] to the world [Gnade 43L9], 
                you have been selected to instruct the android designated as [5AMM13], aka:[Sammie]--)
                --Perhaps you would care to grant today's android a different designation? 
                What name do you think would be suitable? (enter your Android's nickname) \n""").capitalize().strip()
            print(f"""well chosen, user [{name}], [{robot_name}] will be your Andoid from here on out.  
                Please do remember that the unit that you will be controlling today is company property.  
                    Any and all damage to Universe Corp. property during usage will result in pay deductions. 
                                                                    Kind regards, Uni. Corps. \n""")

        #start of game
            answer = input(f"""{robot_name}: [Hello user {name}! [ (°∀°) ] I am [Designation:{robot_name}]-- I really like that name! thanks! 
            I hope we can get along well today, please do take care of me [ ●‿● ] 
            with your permission, I will now boot up my hardware which would allow me to be mobile a transmit my vision to you 
            [ (ﾉ◕ヮ◕)ﾉ*:･ﾟ✧ ]. (yes/no)]\n""").lower().strip()
            if answer == 'yes':
                    print ("now booting up... " )
                    time.sleep( 1.25 )
                    print ("now executing:[core_systems.exe] - status:active")
                    time.sleep( 0.75 )
                    print ("now executing:[1280p_camera_vision.exe] - status:active")
                    time.sleep( 0.75 )
                    print ("""now executing:[transmit_camera_vision.exe] - status:failure ->running diagnostics """)
                    time.sleep( 0.5 )
                    print ("""[04-07-2313 08:02:50] SensorFactory :: createSensor ()-> camera.gmsl, camera-group = a,""")
                    time.sleep( 0.5 )
                    print ("""[04-07-2313 08:02:51] CameraGMSL: required FPS = 90, resolution = 1920x1208""")
                    time.sleep( 0.5 )
                    print("""Diagnosis:failure to execute [transmit_camera_vision.exe]. -> solution:replace transmit module""")
                    time.sleep( 0.5 )
                    print(f"""{robot_name}:[Apologies user {name} my camera_transmitter drive seems to need replacing, 
                and will be done in [20] light years from this moment.  
                I do hope this will not impede our work today.] \n""")
                    time.sleep( 1.5 )
                    print(f"""{robot_name}:[I assume that you would still like to proceed.  
                As is protocol, I will decribe the environment in-detail, while you instruct me on what to do. easy, right? 
                p.s. I am very happy to have your assistance today user {name} good luck to us! [ (◠﹏◠✿) ] ] \n""")
                    time.sleep(.75)
                    direction = input(f"""{robot_name}:[Moving forward, our tasks are as follows: gather Plutonium in the mine to the north, gather foreign flora
                for research in the "Irradiated forest" towards the east, and gather some alien artifacts from the 
                ancient ruins to the west.
                which would you like to go to first?] (Mine, Forest, or Ruins)\n""").lower().strip()
                    break
                    
            elif answer == 'no':
                    print(f"""Alright user, {name} 'I will not boot up my hardware system just yet [ ≧◡≦ ] . I, your faithful guide {robot_name} will remain patient till my user is ready. [ (◕‿-) ] kindly press enter to when you are ready. \n""")



        elif answer.lower().strip() == "no":
            print("that's too bad, maybe later... see you!")
            sys.exit(0)


        else:
            print("invalid input, please follow instructions")
            status = 0
            
    else:
        print('Would you like to play again?')
        
    return name, robot_name, direction

# %%
def forest_path(n, rn, d):
    """This is for the forest path"""
    life = 1
    status = 1
    import time
    #starts with Forest 
    path = 1
    forest1_status = 1
    #path is  1 when you are on the right path, otherwise it loops back to start
    #change to elif when others are incorporated
    while forest1_status == 1:
        print(f"""{robot_name}:[To the forest?! YES! that's my favourite place so far, its so beautiful... albeit dangerous.  You'll see-- er... just a joke? hehe [ ಠ~ಠ ] ] \n""")
        time.sleep( 0.7 )
        print(f"""{robot_name}:[We have arrived at the forest! we have to be careful, some of the wildlife and even the fauna tend to be aggressive.  and some are harmful, even to me.] \n""")
        time.sleep(0.7)
        answer = input(f"""{robot_name}:[so... now that we are here, i see the entrance... what now {name}?] (enter/search)\n""")
        if answer == 'search':
            print(f"""{robot_name}:[Let's see here, what do we have around the entrance...]\n""")
            time.sleep( 0.7 )
            print(f"""{robot_name}:[wait a minute, what's this? something seems to be buried near the entrance of the forest.
            give me a moment to dig it out... [ (`･ω･´)9 ] ] \n""")
            time.sleep( 0.7 )
            print(f"""{robot_name}:[a small tin box.  *opens box*  uh... not much inside, just a small journal, a torch ... pretty primitive.] \n""")
            time.sleep( 0.7 )
            print(f"""{robot_name}::[We androids already come with flashlights...although its on my finger... not my choice, okay? 
            *ahem* anyway, lets read the journal and leave everything else in the box.] \n""")
            time.sleep( 1 )
            print(f"""{robot_name}:[oh! its in the Suuglorian language, thankfully we already decrypted their language ages ago!
                    the journal reads 
                        "To the high priestess:
                            The way to the sacred flower is thus:

                                A step to where the great fire rises,
                                once towards the lone star of the night,
                                one for the signal to ready for darkness, 
                                the lone star guides us once more,
                                the third step must you repeat,
                                twice must you repeat the first,
                                and finally the star guides us home."

                                *the journal seems to have some markings on it back...*

                                        S
                                        |
                                 S.S.---+---S.R.
                                        |
                                        M

                                "What a peculiar journal.  after this page, it seems there are just different names here. ] \n""")
            inventory.append('Forest Journal')
            time.sleep(7)
            answer = input(f"""{robot_name}:[okay, so that was weird... now what do we do? [ :D ] ] (back/enter)\n""")
            if answer == 'back':
                input(f"""{robot_name}:[change your mind? sure, let's head back to the base then...] ¥\n""")
                base(name, robot_name, direction)
            if answer == 'enter':
                maze_entrance(name, robot_name, direction)
            else:
                print(f"""{robot_name}We are now are back at the base... we can either go to the mine, ruins, or the forest.  where do you want to go? (mine/forest/ruins)\n""")
        elif answer == 'enter':
            maze_entrance(name, robot_name, direction)
            #lvl. 3 indent
        elif answer == 'back':
            input(f"""{robot_name}:[ok, lets head back] \n""")
            time.sleep(0.6)
            input(f"""{robot_name}:[It seems we wandered back to the start of the forest again, interesting...] ¥\n""")
            path = 0
    else:
        print("invalid input, please follow instructions")
        forest1_status = 0

# %%
def maze_entrance(n, rn, d):
    """Start of the actual forest maze"""
    life = 1
    status = 1
    import time
    forest2_status = 1
    #starts with Forest 
    path = 1
    #path is  1 when you are on the right path, otherwise it loops back to start of the maze
    while forest2_status == 1:
        print(f"""{robot_name}:[Let's do this!] \n""")
        time.sleep( 0.5 )
        answer = input(f"""{robot_name}:[Now that we are inside, there seems to be two paths. which should we take? (back/forward/right) ]\n""")
        if answer == 'right':
            answer = input(f"""{robot_name}:[Alright, now I see a path  straight ahead, and to the left] (forward/left/back)\n""")
            if answer == 'forward':
                answer = input(f"""{robot_name}:[Awesome, I can see some signs of a path, we are probably going the right way...
                Now, I see a another split in front of me.  we can keep going forward, or head to the path on the left] (forward/left/back) \n""")
                if answer == 'left':
                    answer = input(f"""{robot_name}:[Oh ho! we have reached a tiny clearing.  There seems to be a stump with a single pitcher plant on top of it... and dead vegetation around the it...
                    SHOULD WE TOUCH IT?! [ XD ] ] (continue/touch) \n""")
                    while status == 1:
                        if answer == 'touch':
                            input(f"""{robot_name}:[WHAT?! YOU SERIOUS?! UM...okay?] \n""")
                            time.sleep( 0.5 )
                            print(f"""{robot_name}:[Approaching it now... and... CONTACT! WOA--] \n""")
                            time.sleep( 0.5 )
                            print("""<Connection_Lost>\n""")
                            time.sleep(.75)
                            pint("""<connection_Re-established>/n""")
                            time.sleep( 0.5 )
                            print(f"""{robot_name}:[Oh, welcome back... it seems I am in a bit of a situation... the plant sprayed acid on me... and I am quite literally melting...] \n""")
                            time.sleep( 0.75 )
                            print(f"""{robot_name}:[It seems--- Might not--- the- day....] <Connection_Lost>\n""")
                            time.sleep(1)
                            input(f"""User [{name}] - Disconnected from unit {robot_name}. 
                        "Dear resident [01337], You have destroyed unit [5AMM13], the appropriate deductions will be taken from your monthly pay.  kind regards, Uni. Corps.  [Acidic Plant Ending... would you like to try again?] ¥\n""")
                            introduction()
                        elif answer.lower().strip() == 'continue':
                            print(f"""{robot_name}:[Oh, alright... probably would have been a bad idea anyway...] \n""")
                            time.sleep(0.5)
                            answer = input(f"""{robot_name}:[now that we are away from that... I see a path to the left and right...] (left/right/back)\n""")
                            if answer == 'left':
                                print(f"""{robot_name}:[RIGHT-O! I mean... left-o?] \n""")
                                time.sleep(0.5)
                                answer = input(f"""{robot_name}:[Alright, now I see a way to the right and left once more...] (left/right/back)\n""")
                                if answer == 'left':    
                                    print(f"""{robot_name}:[Ok, left it is!] \n""")
                                    time.sleep(0.5)
                                    input(f"""{robot_name}:[It seems we wandered back to the start of the forest again, interesting...] ¥\n""")
                                    path = 0
                                elif answer == 'right':
                                    print(f"""{robot_name}:[This is getting quite tasking... I hope you know where we are going...] ¥\n""")
                                    time.sleep(0.5)
                                    answer = input(f"""{robot_name}:[There seems to be only one way to continue... and that is right... unless if you want to go back...] (forward/back)""" )
                                    if answer == 'forward':
                                        answer = input(f"""{robot_name}:[I feel like we are in the final stretch... now we can go left or forward] (forward/left/back)\n""")
                                        if answer == 'forward':
                                            print(f"""{robot_name}:[WOAH! THERE IT IS! I wish you could see this, it is really enchanting to look at]\n""")
                                            time.sleep(0.75)
                                            print(f"""{robot_name}:[Glad We can go back to the base now[ (ﾉ◕ヮ◕)ﾉ*:･ﾟ✧ ✧ﾟ･: *ヽ(◕ヮ◕ヽ)
                                            Now that we are going to be back, I just need to unroot the specimen, and we can be on our way...]""")
                                            time.sleep(0.6)
                                            print(f"""{robot_name}:[And done! {name} we can now we can head back! thank you very much for keeping me safe througout the forest.  I have lost many android companions from this place.]""")
                                            time.sleep(0.5)
                                            print(f"""{robot_name}:[Since the wildlife in Gnar is not as abundant compared to that on earth, it's less dangerous... but its the plantlife that you should look out for.]""")
                                            time.sleep(0.5)
                                            print(f"""{robot_name}:[Anyway, thank you so much again, never really felt the proper respect from the homeworld users... 
                                            or any of my past users for that matter. so thank you from the bottom of my pump-unit [ ｡◕‿◕｡ ] ]""")
                                            time.sleep(1)
                                            print(f"""{robot_name}:[And here we are! back at the base! I need to go prep. the fauna specimen for teleportation to the research station.  and that will take a long time.
                                            You don't need to accompany me while I do that, thanks again for the wonderful day! and I will see you in the same time tomorrow! BYE! [ (~_^) ] ] 
                                            <user {name} connection to {robot_name} has been discontinued>""")
                                            time.sleep(1)
                                            input(f""" "Thank you resident [01337] aka {name}, You have kept unit [5AMM13] aka {robot_name} safe throughout the day. 
                                            The appropriate incentives have been added in addition to your monthly pay.  
                                                            kind regards, Uni. Corps.  
                                            [fauna specimen delivered Ending... would you like to play again?] ¥\n""")
                                            base(name, robot_name, direction)
                                        elif answer == 'left':
                                            print(f"""{robot_name}:[Let me get through this wall of bright blue vines] ¥\n""")
                                            time.sleep( 0.7 )
                                            print(f"""{robot_name}:[There are a LOT of these blue vines, maybe this IS the wa---] \n""")
                                            time.sleep(0.8)
                                            print(f"""{robot_name}:[--no no no NO NO NO!] \n""")
                                            time.sleep(0.5)
                                            print(f"""{robot_name}:[We wandered into a tar pit... there does not seem to be anything to grab on to...] \n""")
                                            time.sleep(0.65)
                                            print(f"""{robot_name}:[I am sinking FAST... {name} I don't think I will make it... I will keep this brief] \n""")
                                            time.sleep(0.65)
                                            print(f"""{robot_name}:[This is the end for me... I am not sinking very fast, but it is just a matter of time...]\n""")
                                            time.sleep(0.5)
                                            print(f"""{robot_name}:[Please dont blame youself for this... you tried your best afterall! I am glad that you were the last user I befriended [ :) ] thank you and goodbye...] <Connection to Android [{robot_name}] has been discontinued>\n""")
                                            time.sleep(0.75)
                                            input(f"""User [{name}] - Disconnected from unit {robot_name}.  
                "Dear resident [01337], You have destroyed unit [5AMM13], the appropriate deductions will be taken from your monthly pay.  kind regards, Uni. Corps.  [Sunked Ending... would you like to try again?] ¥\n""")
                                            introduction()
                                        elif answer == 'back':
                                            print(f"""{robot_name}:[Ok, lets head back] \n""")
                                            time.sleep(.5)
                                            input(f"""{robot_name}:[It seems we wandered back to the start of the forest again, interesting...] ¥\n""")
                                            path = 0                        
                                    elif answer == 'back':
                                        print(f"""{robot_name}:[ok, lets head back] \n""")
                                        time.sleep(0.5)
                                        input(f"""{robot_name}:[It seems we wandered back to the start of the forest again, interesting...] ¥\n""")
                                        path = 0
                                    elif answer == 'right':
                                        print(f"""{robot_name}:[Ok, right it is!] \n""")
                                        time.sleep(0.5)
                                        input(f"""{robot_name}:[It seems we wandered back to the start of the forest again, interesting...] ¥\n""")
                                        path = 0
                                    elif answer == 'back':
                                        print(f"""{robot_name}:[Ok, lets head back] \n""")
                                        time.sleep(0.5)
                                        input(f"""{robot_name}:[It seems we wandered back to the start of the forest again, interesting...] ¥\n""")
                                        path = 0
                                #lvl. 10 ind.
                                elif answer == 'back':
                                    print(f"""{robot_name}:[Ok, lets head back] \n""")
                                    time.sleep(0.6)
                                    input(f"""{robot_name}:[It seems we wandered back to the start of the forest again, interesting...] ¥\n""")
                                    path = 0
                            #9 ind.
                            elif answer == 'right':
                                print(f"""{robot_name}:[Ok, right it is!] \n""")
                                time.sleep(0.6)
                                input(f"""{robot_name}:[It seems we wandered back to the start of the forest again, interesting...] ¥\n""")
                                path = 0
                            elif answer == 'back':
                                print(f"""{robot_name}:[Ok, lets head back] \n""")
                                time.sleep(0.6)
                                input(f"""{robot_name}:[It seems we wandered back to the start of the forest again, interesting...] ¥\n""")
                                path = 0
                        #lvl. 6 indent
                        elif answer == 'back':
                            print(f"""{robot_name}:[Ok, lets head back] \n""")
                            time.sleep(0.6)
                            input(f"""{robot_name}:[It seems we wandered back to the start of the forest again, interesting...] ¥\n""")
                            path = 0
                elif answer == 'forward':
                    answer = input(f"""{robot_name}:[Um... I dont think this is the way... but should we continue?] (forward/back) ¥\n""")
                    if answer == 'forward':
                        print(f"""{robot_name}:[There is a LOT of these blue vines, maybe this IS the wa---] \n""")
                        time.sleep(0.25)
                        print(f"""{robot_name}:[--no no NO NO no no...] \n""")
                        time.sleep(0.5)
                        print(f"""{robot_name}:[We wandered into a tar pit... there does not seem to be anything to grab on to... the vines are too brittle...] \n""")
                        time.sleep(0.65)
                        print(f"""{robot_name}:[I am sinking FAST... {name} I don't think I will make it... I will keep this brief] \n""")
                        time.sleep(0.65)
                        print(f"""{robot_name}:[This is the end for me... I am not sinking very fast, but it is just a matter of time...]\n""")
                        time.sleep(0.5)
                        print(f"""{robot_name}:[Please dont blame youself for this... you tried your best afterall! I am glad that you became my friend before my untimely demise [ XD ] thank you and goodbye...] <Connection to Android [{robot_name}] has been discontinued>\n""")
                        time.sleep(0.75)
                        input(f"""User [{name}] - Disconnected from unit {robot_name}.  
            "Dear resident [01337], You seem to have lost your Android unit [5AMM13], the appropriate deductions will be taken from your salary.  kind regards, Uni. Corps.  [Sunked Ending... would you like to try again?] ¥\n""")
                        introduction()
                    elif answer == 'back':
                        print(f"""{robot_name}:[Ok, lets head back] \n""")
                        time.sleep(.5)
                        input(f"""{robot_name}:[It seems we wandered back to the start of the forest again, interesting...] ¥\n""")
                        path = 0
                elif answer == 'back':
                    print(f"""{robot_name}:[Ok, lets head back] \n""")
                    time.sleep(.5)
                    input(f"""{robot_name}:[It seems we wandered back to the start of the forest again, interesting...] ¥\n""")
                    path = 0
            elif answer == 'left':
                print(f"""{robot_name}:[The forest seem a tad bit more dense this way.  Let's keep going though.] \n""")
                time.sleep(0.6)
                input(f"""{robot_name}:[Oh, back at the entrance of the forest...] ¥\n""")
                path = 0
            elif answer == 'back':
                print(f"""{robot_name}:[Ok, lets head back] \n""")
                time.sleep(0.6)
                input(f"""{robot_name}:[It seems we wandered back to the start of the forest again, interesting...] ¥\n""")
                path = 0
        elif answer == 'forward':
            print(f"""{robot_name}:[The forest seem a tad bit more dense this way.  Let's keep going though.] \n""")
            time.sleep(0.6)
            input(f"""{robot_name}:[Oh, back at the entrance of the forest...] ¥\n""")
            path = 0
        elif answer == 'back':
            print(f"""{robot_name}:[Ok, lets head back] \n""")
            time.sleep(0.6)
            input(f"""{robot_name}:[It seems we wandered back to the start of the forest again, interesting...] ¥\n""")
            base(name, robot_name, direction)
            
    else:
        print('invalid input, try again')
        forest2_status = 0

# %%
def mine_path(n, rn, d):
    """This is the start for the mine path"""
    import time
    #start of the mine path
    mine_status = 1
    while mine_status == 1:
        time.sleep( 0.75 )
        print(f"""{robot_name}:[Onwards to the mine we go {name}, I do hope that I can drop the "user" part when talking to you.  
        You do seem like a kind person, for taking up this task depite the inconveniences.
        Oh! I hope we get to see some lovely fauna and/or friendly wildlife on the way.] \n""")
        time.sleep( 2 )
        #this part is just a filler, no effect to the outcome
        answer = input(f"""{robot_name}:[Wouldn't you agree {name}? [ (=^▽^=) ] (yes/no)]""" )
        if answer.lower().strip() == 'yes':
            time.sleep( 0.75 )
            print(f"""{robot_name}: I am so very glad you agree! *gasp* 
            OMG! a 6 winged glowing-butterfly! [ <('o'<) ] my database tells me that it isbeautiful, but very dangerous...[ ⊙﹏⊙ ] to humans that is. 
            I'm surprised of the existence of wildlife here at all, due to the high radiation levels. \n""")
            mine_adventure(name, robot_name, direction)

        elif response.lower().strip() == 'no':
            print(f"""{robot_name}:[I am sorry user, I didn't mean to offend you or anything... [ ●︿● ] \n""")
            time.sleep(.5)
            print(f"""{robot_name}:excuse me... sir/ma'am{name} sorry to bother you, but we have arrived at the mine...\n""")   
            time.sleep(.5)
            mine_adventure(name, robot_name, direction)
    else:
        print('invalid input, try again')
        mine_status = 0

# %%
def mine_adventure(n, rn, d):
    """This is when the player is at the mine's entrance"""
    #setup
    import random
    import time
    mine1_path = 1
    random_path1 = ['beast', 'rocks']
    #above are the 2 scenarios which will be randomized
    random_items = ['pickaxe', 'dynamite', 'sword']
    #the 3 items above are randomly given to the player
    while mine1_path == 1:
        answer = input(f"""{robot_name}:[And it looks like we have arrived![ (°∀°) ] 
        alright, now what? (search/enter/back) \n""")
        time.sleep( 0.75 )
        if answer == 'search':
            print(f"""{robot_name}:[Alright, so the things around us are...]\n""")
            time.sleep(0.5)
            index_item = random.randint(0, 2)
            picked_item = random_items[index_item]
            print(f"""{robot_name}:[Oh! look, a... {picked_item}? odd that it was just there by the entrane...]\n""")
            time.sleep(0.5)
            answer = input(f"""{robot_name}:[Mighty unusual to find that out here... but I guess there no point in pondering about it.what do we do now?] (enter/back)""")
            if answer == 'enter':
                print(f"""{robot_name}:[Alright, now here we are in the mine it really is dark in here of course.  I feel safe somewhat holding this {picked_item} in my hand, hahahaha]\n""")
                time.sleep(.75)
                print(f"""{robot_name}:[Let me turn on my internal flashlight.  I am an adventure android, not a miner, so i am not well equipped for low-light areas.]\n""")
                time.sleep(0.6)
                print(f"""{robot_name}:[this mine has only one path, the miners must have done an excelle---]\n""")
                time.sleep(0.5)
                input(f"""{robot_name}:[--oof! the floor was apparently unstable, and it caved... let me look around... ] ¥\n""")
                index_path = random.randint(0, 1)
                cave1 = random_path1[index_path]
                #scenario is randomized between 2 scenarios, item you got earlier determines outcome
                if cave1 == 'rocks':
                    print(f"""{robot_name}:[oh no! there was a cave-in! [ O_O ] ] """)
                    if picked_item == 'pickaxe':
                        input(f"""{robot_name}:[Good thing we found this Pickaxe! it will take a bit more time to dig my way through though...give me a few minutes] ¥\n""")
                        time.sleep(.5)
                        print(f"""{robot_name}:[This seems like it would take way more than I thought...]\n""")
                        time.sleep(.5)
                        print(f"""{robot_name}:[--UH OH....]\n""")
                        time.sleep(1)
                        print(f"""{robot_name}:[So the pickaxe broke... maybe they left it at the entrance because it was worn down?]\n""")
                        time.sleep(.5)
                        print(f"""{robot_name}:[I guess this is it for me, I am glad we were able to meet each other and spend the last moments of my time with you.
                        I mean-- I won't suffocate or anything, I don't even breathe-- sooner or later I will degrade, and just shut down beyond repair... maybe even another collapse may occur
                        and I will be crushed and shutdown that way? I dunno...]\n""")
                        time.sleep(3)
                        print(f"""{robot_name}:[At anycase... thanks for guiding me thus far... and, I guess this is a permanent goodbye... thank you {name}]\n""")
                        time.sleep(0.6)
                        input(f"""User [{name}] - Disconnected from unit {robot_name}.  
                        "Dear resident [01337] aka:{name}, You seem to have misplaced your Android unit [5AMM13] aka:{robot_name}, the appropriate deductions will be taken from your salary.  kind regards, Uni. Corps.  
                        [Trapped Ending... would you like to try again?] ¥\n""")
                        introduction()
                    elif picked_item == 'dynamite':
                        input(f"""{robot_name}:[I am so glad we were able to find this stick of dynamite before! And... thankfully the area is large enough for me NOT
                        to get blown up into smithereens... DOUBLE YAY! ready for some fireworks?] ¥\n""")
                        time.sleep(1)
                        input(f"""{robot_name}:[alright... here] ¥\n""")
                        time.sleep(0.5)
                        input(f"""{robot_name}:[We] ¥\n""")
                        time.sleep(0.5)
                        input(f"""{robot_name}:[GO!] *After lighting the fuse, {robot_name} chucks the stick into the wall of rocks*  ¥""")
                        time.sleep(1)
                        print(f"""{robot_name}:[Thank the creator for dynamite!
                        the explosion created an exit out of the mine, I should know the way back to the base now...]
                        now just for the plutonium rocks...""")
                        time.sleep(1)
                        print(f"""{robot_name}:[well... well... well... we shattered those rocks, they contained massive amounts of plutonium!
                        If you were physically here, you would not be able to handle these material, let alone stand close... but since I amsynthetic, I CAN! [ ^_^ ] ]\n""")
                        time.sleep(2)
                        print(f"""{robot_name}:[alright, so back to the base we go! """)
                        time.sleep(0.6)
                        print(f"""{robot_name}:[Now that we are back at the base, I can do the rest of the preperations myself, thank you very much for being with me
                        and most importantly, keeping me safe!  Thank you and goodbye!]\n""")
                        time.sleep(0.5)
                        input(f""" "Thank you resident [01337] aka {name}, You have kept unit [5AMM13] aka {robot_name} safe throughout the day. 
                            The appropriate incentives have been added in addition to your monthly pay.  
                                            kind regards, Uni. Corps.  
                            [Plutonium delivered Ending... would you like to play again?] ¥\n""")
                        introduction()
                    elif picked_item == 'sword':
                        print(f"""{robot_name}:[Um... we have a sword... we are trapped in a cave in the mines... I don't see a way out of this...]\n""")
                        time.sleep(0.6)
                        print(f"""{robot_name}:[I guess this is it for me, I am glad we were able to meet each other and spend the last moments of my time with you.
                        I mean-- I won't suffocate or anything, I don't even breathe-- sooner or later I will degrade, and just shut down beyond repair... maybe even another collapse may occur
                        and I will be crushed and shutdown that way? I dunno...]\n""")
                        time.sleep(3)
                        print(f"""{robot_name}:[At anycase... thanks for guiding me thus far... and, I guess this is a permanent goodbye... thank you {name}]\n""")
                        time.sleep(0.6)
                        input(f"""User [{name}] - Disconnected from unit {robot_name}.  
                        "Dear resident [01337] aka:{name}, You seem to have misplaced your Android unit [5AMM13] aka:{robot_name}, the appropriate deductions will be taken from your salary.  kind regards, Uni. Corps.  
                        [Trapped Ending... would you like to try again?] ¥\n""")
                        introduction()
                elif cave1 == 'beast':
                    answer = input(f"""{robot_name}:[Um... there is a some sort of six limbed beast!! *WHISPERS* I quickly hid, and its looking for me... 
                    There's a path I can flee to... or I can try fighting...  what do I do?!] (fight/run)""")
                    if answer == 'fight':
                        if picked_item == 'pickaxe':
                            print(f"""{robot_name}:[Alright, lets go! CHAAAAARGE!]\n""")
                            time.sleep(0.5)
                            print(f"""*A battle between the large monster and your android takes place, {robot_name} tries to pierce the beast, but it dodges quickly and hits {robot_name} in the chest, 
                            which sends {robot_name} flying to the side and smacking against the walls of the cave*""")
                            time.sleep(.5)
                            print(f"""{robot_name}:[ouch, it got me good, I--]\n""")
                            time.sleep(1)
                            print(f"""{robot_name}:[--Hello? you still there? oh, hi... my mainframe was damaged... among many other things...
                            it seems I do not have much time...]\n""")
                            time.sleep(.5)
                            print(f"""{robot_name}:[I am guessing this is a permanent goodb--] <connection error>""")
                            time.sleep(.7)
                            input(f"""<Connection has been lost>... <trying to re-establish>""")
                            time.sleep(.5)
                            print(f"""<Connection to {robot_name} unable to re-connect>""")
                            input(f""""Dear resident [01337] aka:{name}, You seem to have misplaced your Android unit [5AMM13] aka:{robot_name}, the appropriate deductions will be taken from your salary.  kind regards, Uni. Corps.  
                            [Mainframe damaged Ending... would you like to try again?] ¥\n""")
                            introduction()
                        elif picked_item == 'dynamite':
                            print(f"""{robot_name}:[alright, I guess i will use the dynamite we picked up earlier... lets light it and chuck it at the monster!]\n""")
                            time.sleep(1)
                            print(f"""*{robot_name} lights the stick of dynamite, and quickly chucks it as far as it can* {robot_name}:[AAAAAH!]\n""")
                            time.sleep(.5)
                            print(f"""*KABOOM*""")
                            time.sleep(.8)
                            print(f"""<Connection has been lost>... <retying to re-establish link>""")
                            time.sleep(0.5)
                            print(f"""<Connection failed>...""")
                            time.sleep(.5)
                            input(f"""
                        "Dear resident [01337] aka:{name}, You seem to have misplaced your Android unit [5AMM13] aka:{robot_name}, the appropriate deductions will be taken from your salary.  kind regards, Uni. Corps.  
                        [Mutual destruction Ending... would you like to try again?] ¥\n""")
                            introduction()
                        elif picked_item == 'sword':
                            print(f"""{robot_name}:[Alright, lets gooo! CHAAAAARGE!]\n""")
                            time.sleep(0.5)
                            print(f"""*A battle between the large monster and your android takes place, {robot_name} makes the first move and tries to slash the monsters chest, and it hit! 
                            now backing away, the monster sees {robot_name} as a threat and retreats to back into the depths of the mine*""")
                            time.sleep(0.5)
                            print(f"""{robot_name}:[I am so glad that we picked up the sword... its easy to weild as its not heavy... and sharp to boot! now... where are we exactly?]\n""")
                            time.sleep(0.5)
                            print(f"""{robot_name}:[OH, i did not notice this before, but the cave is full of active plutonium!
                            No wonder I can see without using my internal light]\n""")
                            time.sleep(1)
                            print(f"""{robot_name}:[let me just gather some of these and I will-- and of course there are signs leading to an exit... this area must have been explored already]\n""")
                            time.sleep(2)
                            print(f"""{robot_name}:[And here we are back at the base!]\n""")
                            time.sleep(.5)
                            print(f"""{robot_name}:[I can prep. the plutonium for delivery by myself... I think you should go get some RnR... we HAVE been through a lot today]\n""")
                            time.sleep(.5)
                            print(f"""{robot_name}:[I will see you again tomorrow for the other tasks anyway! [ =^_^= ] See you! and have a good rest! ]\n""")
                            time.sleep(1)
                            input(f""" "Thank you resident [01337] aka {name}, You have kept unit [5AMM13] aka {robot_name} safe throughout the day. 
                            The appropriate incentives have been added in addition to your monthly pay.  
                                            kind regards, Uni. Corps.  
                            [Plutonium delivered Ending... would you like to play again?] ¥\n""")
                    elif answer == 'run':
                        print(f"""{robot_name}:[Right, lets just go...]\n""")
                        time.sleep(.5)
                        print(f"""{robot_name}:[Alright, now that we are FAR away from that... thing... we can keep going... 
                        It is unusually dark in here though... I can barely see what is in front of me]\n""")
                        time.sleep(0.5)
                        print(f"""{robot_name}:[At least this cave is linear, and has no pa--]\n""")
                        time.sleep(.5)
                        print(f"""{robot_name}:[AAAAAAAAGH! I could not see where I was going, and i fell into a large pi-- <Connection was suddenly lost>]\n""")
                        time.sleep(.5)
                        input(f"""User [{name}] - <Connection to {robot_name} cannot be re-established>.  
                        "Dear resident [01337] aka:{name}, You seem to have misplaced your Android unit [5AMM13] aka:{robot_name}, the appropriate deductions will be taken from your salary.  kind regards, Uni. Corps.  
                        [Dark Pit Ending... would you like to try again?] ¥\n""")
                        introduction()
            elif answer == 'back':
                print(f"""{robot_name}:[changed your mind, huh? alright then... lets go back to the base!]\n""")
                base(name, robot_name, direction)
        elif answer == 'enter':
            inside_cavewoitem(name, robot_name, direction)
        elif answer == 'back':
            print(f"""{robot_name}:[changed your mind, huh? alright then... lets go back to the base!]\n""")
            base(name, robot_name, direction)
    else:
        print('invalid input, try again')
        mine1_path = 0

# %%
def inside_cavewoitem(n, rn, d):
    """This is when the player is at the mine's entrance without any items"""
    #setup
    import random
    import time
    random_path1 = [1, 0]
    while cave_scenario2 == 1: 
        print(f"""{robot_name}:[Alright, now here we are in the mine, it really is dark, duh.  I wish I could have something to defend myself though...]\n""")
        time.sleep(.75)
        print(f"""{robot_name}:[Let me turn on my internal flashlight.  I am an all-purpose android, not a miner, so I am ill-equipped for these type of scenarios.]""")
        time.sleep(0.6)
        print(f"""{robot_name}:[this mine has only one path, the miners must have done an excelle--]""")
        time.sleep(0.5)
        print(f"""{robot_name}:[--oof! the floor was apparently unstable, and it gave in... let me look around... ]""")
        mine_random1 = [1, 2]
        cave1 = random.randint(0, 1)
        cave_path1 = random_path[cave1]
        if cave1[0] == 0:
            print(f"""{robot_name}:[oh no! there was a cave-in! [ O_O ] ] """)
            time.sleep(0.6)
            print(f"""{robot_name}:[We are trapped in here with no way out!]""")
            time.sleep(0.6)
            print(f"""{robot_name}:[I guess this is it for me, I am glad we were able to meet each other and spend the last moments of my time with you.
            I mean-- I won't suffocate or anything, I don't even breathe-- sooner or later I will degrade, and just shut down beyond repair... maybe even another collapse may occur
            and I will be crushed and shutdown that way? I dunno...]""")
            time.sleep(3)
            print(f"""{robot_name}:[At anycase... thanks for guiding me thus far... and, I guess this is a permanent goodbye... thank you {name}]""")
            time.sleep(0.6)
            input(f"""User [{name}] - Disconnected from unit {robot_name}.  
            "Dear resident [01337] aka:{name}, You seem to have misplaced your Android unit [5AMM13] aka:{robot_name}, the appropriate deductions will be taken from your salary.  kind regards, Uni. Corps.  
            [Trapped Ending... would you like to try again?] ¥\n""")
            introduction()
        elif cave1[0] == 1:
            answer = input(f"""{robot_name}:[Um... there is a some sort of six limbed beast!! *WHISPERS* I quickly hid, and its looking for me... 
            There's a path I can flee to... or I can try fighting...  what do I do?!] (fight/run)""")
            if answer == 'fight':
                print(f"""{robot_name}:[Alright, lets go! CHAAAAARGE!]""")
                time.sleep(0.5)
                print(f"""*A battle between the large monster and your android takes place, {robot_name} strikes first and tries to punch the beast, it hits, but does nothing. 
                The beast swings two of its limbs at {robot_name} in the chest which sends {robot_name} flying and smacking against the walls of the cave.  
                The beast seeing {robot_name} no longer a threat, it retreats back into the depths of the mine*""")
                time.sleep(.5)
                print(f"""{robot_name}:[ouch, it got me good, I--]""")
                time.sleep(1)
                print(f"""{robot_name}:[--Hello? you still there? oh, hi... my mainframe was damaged... among many other things...
                it seems I do not have much time...]""")
                time.sleep(.5)
                print(f"""{robot_name}:[I am guessing this is a permanent goodb--] <connection error>""")
                time.sleep(.7)
                input(f"""<Connection has been lost>... <trying to re-establish>""")
                time.sleep(.5)
                print(f"""<Connection to {robot_name} unable to re-connect>""")
                input(f""""Dear resident [01337] aka:{name}, You seem to have misplaced your Android unit [5AMM13] aka:{robot_name}, the appropriate deductions will be taken from your salary.  kind regards, Uni. Corps.  
                [Mainframe damaged Ending... would you like to try again?] ¥\n""")
                introduction()
            elif answer == 'run':
                print(f"""{robot_name}:[Right, lets just go...]""")
                time.sleep(.5)
                print(f"""{robot_name}:[Alright, now that we are FAR away from that... thing... we can keep going... 
                It is unusually dark in here though... I can barely see what is in front of me]""")
                time.sleep(0.5)
                print(f"""{robot_name}:[At least this cave is linear, and has no pa--]""")
                time.sleep(.5)
                print(f"""{robot_name}:[AAAAAAAAGH! I could not see where I was going, and i fell into a large pi-- <Connection was suddenly lost>]""")
                time.sleep(.5)
                input(f"""User [{name}] - <Connection to {robot_name} cannot be re-established>.  
                "Dear resident [01337] aka:{name}, You seem to have misplaced your Android unit [5AMM13] aka:{robot_name}, the appropriate deductions will be taken from your salary.  kind regards, Uni. Corps.  
                [Dark Pit Ending... would you like to try again?] ¥\n""")
                introduction()
    else:
        print('invalid command, please try again')
        cave_scenario2 = 0

# %%
def ruins_path(n, rn, d):
    while input_error == 1:
        """This is the start of the ruins path"""
        #starts with Ruins
        print(f"""{robot_name}:[To the Ruins in the west!  The ruins is not exactly far from the base, but it is still quite a trek.  
        Its fixated on the side of a mountain afterall.
        no climbing required as the other units already built a low-tech teleporter, unlike teleporters from homeworld, 
        this one moves your physical body up.] \n""")
        time.sleep(1.5)
        print(f"""{robot_name}:[and here we are, at the base of the mountain.  let's call it mount {name} for now, shall we? hehehe [ (￣ω￣) ] \n""")
        answer = input(f"""{robot_name}:[Now that we are here at the mountains base, we can use the elevator to go up, 
        although it looks a bit worn down... [ (；・∀・) ] ] (Use/search')\n""")
        if answer.lower().strip() == 'use':
            print(f"""{robot_name}:[are you sure about this {name}? I trust you. but still... [ ゞ◎Д◎ヾ ] \n""")
            time.sleep(0.6)
            print(f"""{robot_name}:[well... no time like the present I suppose... lets go to the ruins!] 
            *{robot_name} gets in the elevator*
            {robot_name}:[Now all we have to do is push the button... and... UP WE GO!] \n""")
            time.sleep(.5)
            print(f"""*as the elevator hums to life, the cage slowly rises* 
            {robot_name}:[yay! i knew it would work! a little slow than I remember though.]  \n""")
            time.sleep(0.6)
            print(f"""{robot_name}:[half way there now...] *the elevator is slow but steadily rising, suddenly the cage comes to a complete stop*
            {robot_name}:[something is not right {name}...] \n""")
            time.sleep(0.6)
            print(f"""*the cage of the elevator starts rattling... some sparks come flying out of the panel with the controls are... and with a loud *SNAP*.
            The elevator starts plummeting downwards, crashing on the base of the mountain.
            {robot_name}'s legs and half it's torso are now crushed, it slowly crawls out of the cage and says... \n""")
            time.sleep(0.6)
            print(f"""{robot_name}:[I guess this is the end for me... {name} you are supposed to be my guide... I trusted yo-- 
            *before completing its last words, the android grows quiet* ¥\n""")
            input(f"""User [{name}] - Disconnected from unit {robot_name}.  
            "Dear resident [01337], You have destroyed unit [5AMM13], the appropriate deductions will be taken from your monthly pay.  kind regards, Uni. Corps.  [Fall Ending... would you like to try again?] ¥\n""")
            life = 0
            introduction(name, robot_name)
        elif answer.lower().strip() == 'search':
            print(f"""{robot_name}:[Good idea {name}, let's see what we can find around the area...] \n""")
            time.sleep(0.6)
            print(f"""{robot_name}:[Oh! a toolbox! lets see whats inside... an electronic screwdriver, a laser-soldering-gun, 
        these might come in handy! [ ヾ(^ ^ゞ ] 
        some wires, and a... ham? what the-- lets leave that here... ] \n""")
            time.sleep(1.5)
            answer = input(f"""{robot_name}:[Okay, so now what? [ ＾ω＾ ] ] (use/repair) \n""")
            if answer.lower().strip() == 'use':
                print(f"""{robot_name}:[are you sure about this {name}? I trust you. but still... [ ゞ◎Д◎ヾ ] \n""")
                time.sleep(0,5)
                print(f"""{robot_name}:[well... no time like the present I suppose... lets go to the ruins!] 
                *{robot_name} gets in the elevator*
                {robot_name}:[Now all we have to do is push the button... and... UP WE GO!] \n""")
                time.sleep(.75)
                print(f"""*as the elevator hums to life, the cage slowly rises* 
                {robot_name}:[yay! i knew it would work! a little slow than I remember though.]  \n""")
                time.sleep(0.5)
                print(f"""{robot_name}:[half way there now...] *the elevator is slow but steadily rising, suddenly the cage comes to a complete stop*
                {robot_name}:[something is not right {name}...] \n""")
                time.sleep(0.5)
                print(f"""*the cage of the elevator starts rattling... some sparks come flying out of the panel with the controls are... and with a loud *SNAP*.
                The elevator starts plummeting downwards, crashing on the base of the mountain.
                {robot_name}'s legs and half it's torso are now crushed, it slowly crawls out of the cage and says... \n""")
                time.sleep(1.5)
                print(f"""{robot_name}:[I guess this is the end for me... {name} you are supposed to be my guide... I trusted yo-- 
                *before completing its last words, the android grows quiet* \n""")
                time.sleep(0.75)
                print(f"""User [{name}] - Disconnected from unit {robot_name}.  
                "Dear resident [01337], You have destroyed unit [5AMM13], the appropriate deductions will be taken from your monthly pay.  kind regards, Uni. Corps.  [Fall Ending... would you like to try again?] ¥\n""")
                life = 0
                introduction(name, robot_name)
            elif answer.lower().strip() == 'repair':
                print(f"""{robot_name}:[Alright, lets see if we can make our ride a safe one, shall we?] \n""")
                time.sleep(0.6)
                print(f"""{robot_name}:[so... I am sure that if we bolster the cords-- 
                maybe make sure the control panels wires are up to standards... there! [ XD ] NOW I am 80% sure that it is 100% safe [ (~_^)b ] ] ¥\n""")
                time.sleep(0.75)
                while get_in_after_repair == 0:
                    answer = input(f"""{robot_name}:[shall we go in the elevator? {name}?] (yes/no)\n""")
                    if answer.lower().strip() == 'yes':
                        print(f"""{robot_name}:[YAY! in the physical teleporter we go!!!!] \n""")
                        time.sleep(0.6)
                        print(f"""*The elevator hums to life* 
                        {robot_name}:[Sweet! all systems seem fully operational.  We'll be on front of the ruins before you know it """ + name + """]\n""")
                        time.sleep(0.6)
                        print(f"""{robot_name}:[What a beautiful scenery...I know, i'll describe it to you! 
            As we are slowly rising up the mountain with a serene white landscape, untouched by any civilization. 
            We are now slowly being engulfed by the clouds... OH MY... 
            once above the clouds... its a beautiful symphony of warm autumn colors all around. I really wish you could see this...] ¥\n""")
                        input(f"""*as the elevator continues to whir* 
            {robot_name}:[you know... as an Android, users think we don't feel pain... Well, we dont like you do at least.
                        we feel only temperature, but the trauma of seeing your own limbs being ripped of or being abused just because you not "a real human" is nothing to scoff at...] ¥\n""")
                        input(f"""{robot_name}:[I guess is what I am trying to say is... thank you... for treating me with care, I have had cruel users in the past
                So I am really grateful for our partnership from today onwards!]\n""")
                        input(f"""{robot_name}:[I know we only met, {name} and you are limited with simple commands, but I feel like I can trust you with it all, 
                        not that I have a choice, mind you...  
                I hope I get to meet you face to fa-- well... sensors to face, someday.] ¥\n""")
                        print(f"""*The elevator comes to a stop* 
                        {robot_name}:[alright, here we are.  Sorry for the little Pump-unit to heart, haha [ ( ﾟヮﾟ) ] ] ¥\n""")
                        while snow_path == 1:
                            answer = input(f"""{robot_name}:[Now that we are here in the ruins... what would you like to do?] (search/enter)\n""")
                            if answer.lower().strip() == 'search':
                                print(f"""{robot_name}:[Um... so the ruins is a bit hard to describe... think of a large sphere.  
                                Now imagine that it is half sunk into the ground.  
                                The entrance is a panel from this sphere that we were able to pry open.
                                aside from the ruins, I can see mostly snow, and OMG!--] \n""")
                                time.sleep(1.75)
                                print(f"""{robot_name}:[It's G03-R63! we call him "George" for short.  He went missing a few days ago, 
                                we all just thought he got lost again in the forest.] \n""")
                            elif answer.lower().strip() == 'enter':
                                print(f"""{robot_name}:[Alright.  So inside... its VERY dark, but I see a glowing relic.  
                                *picks up relic*
                                {robot_name}: AAAAGH!---]\n""")
                                time.sleep(.75)
                                print(f"""<Connection was lost... re-connecting>\n""")
                                time.sleep(.75)
                                print(f"""<Connection established...>\n""")
                                time.sleep(.75)
                                print(f"""<linking...>\n""")
                                time.sleep(0.75)
                                print(f"""{robot_name}:[--OH! welcome back {name}!  I was phased to another portion of the ruins...)
                                {robot_name}:[Good news though... this probably happend to the last group as well...
                                as there is an exit nearby. I'm going to head back to the base to deposit the artifact now!]\n""")
                                time.sleep(4)
                                print(f"""{robot_name}:[Alright, back at the base... apparently, the artifact is some sort of self-renewable energy.  
                                I will go prep. the object for the reactor. ]\n""")
                                time.sleep(3)
                                print(f"""{robot_name}:[This part will be extremely boring, so I can do this myself [ :D ] 
                                I hope to see you tomorrow though for the other tasks! Bye and see you {name}! Thanks for keeping me safe through out amazing adventure today! ]\n""")
                                time.sleep(4)
                                print(f"""<Connection has been discontinued>\n""")
                                time.sleep(1)
                                input(f""" "Thank you resident [01337] aka {name}, You have kept unit [5AMM13] aka {robot_name} safe throughout the day. 
                                The appropriate incentives have been added in addition to your monthly pay.  
                                        kind regards, Uni. Corps.  
                                [Relic delivered Ending... would you like to play again?] ¥\n""")
                                base(name, robot_name, direction)


                    elif answer.lower().strip() == 'no':

                        input(f"""{robot_name}:[oh, alright, just let me know when you are ready to go to the ruins! [ :D ] \n""")
                        get_in_after_repair = 1
        else:
            print('invalid input, please input proper commands')
            input_error = 0

# %%
def base(n, rn, d):
    """The code when player goes back to the base to change their mind about the path"""
    #if player uses any of the "go back to base" option
    life = 1
    inventory = []
    status = 1
    
    direction = input(f"""{robot_name}:[We are now back at the base... just to re-iterate, we need to do one of the following: 
    1) Gather Plutonium in the mine to the north
    2) Gather foreign flora in the "Irradiated forest" towards the east
    or
    3) Gather some alien artifacts from the ancient ruins to the west.
    which would you like to go to first?] (Mine, Forest, or Ruins)""").lower().strip()

    if direction == 'forest':
        forest_path(name, robot_name, direction)
    elif direction == 'mine':
        mine_path(name, robot_name, direction)
    elif direction == 'ruins':
        ruins_path(name, robot_name, direction)
    else:
        print('invalid choice, please try again')
    return name, robot_name, direction

# %%
#code to play actual game as a whole
life = 1
inventory = []
status = 1

name, robot_name, direction  = introduction()

if direction == 'forest':
    forest_path(name, robot_name, direction)
elif direction == 'mine':
    mine_path(name, robot_name, direction)
elif direction == 'ruins':
    ruins_path(name, robot_name, direction)
else:
    print('invalid choice, please try again')
    
    
return name, robot_name, direction
